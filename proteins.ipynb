# %%
import pandas as pd
import torch
from transformers import T5Tokenizer, T5Model
import requests
import pickle

# %%
df1 = pd.read_csv('new_chembl_inhibit_drug_target.csv')
df2 = pd.read_csv('cancer_ppi_combined.csv')

# %%
protein_list1 = df1['target_accession_number']

protein_list2 = df2['node1_uniprot_id']

protein_list3 = df2['node2_uniprot_id']

protein_list = pd.concat([protein_list1, protein_list2, protein_list3], ignore_index=True)

protein_list = protein_list.drop_duplicates()

print(len(protein_list))
# Out:
# 5914

# %%
# Load the Prot5 model and tokenizer
tokenizer = T5Tokenizer.from_pretrained("Rostlab/prot_t5_xl_uniref50")
print("Tokenizer loaded")
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Tokenizer loaded

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = T5Model.from_pretrained("Rostlab/prot_t5_xl_uniref50").half().to(device)
print("Model loaded")
# Out:
# Model loaded

# %%
protein_list_1 = protein_list[:2000]
protein_list_2 = protein_list[2000:4000]
protein_list_3 = protein_list[4000:]

# %%
# Function to fetch protein sequence from UniProt
def fetch_uniprot_sequence(uniprot_id):
    url = f"https://www.uniprot.org/uniprot/{uniprot_id}.fasta"
    response = requests.get(url)
    if response.status_code == 200:
        sequence = ''.join(response.text.splitlines()[1:])  # Skip the FASTA header
        return sequence
    else:
        print(f"Error fetching sequence for {uniprot_id}")
        return None

# Function to generate embeddings for a list of protein sequences
def get_protein_embeddings(uniprot_ids):
    embeddings_dict = {}  # Dictionary to cache embeddings
    num = 0

    for uniprot_id in uniprot_ids:
        num += 1
        if num%20 == 0:
            print(f"Processing uniprot id : {uniprot_id} number {num}")

        try:
            sequence = fetch_uniprot_sequence(uniprot_id)  # Fetch the protein sequence
            if sequence:
                # Tokenize the input sequence
                inputs = tokenizer(sequence, return_tensors="pt", padding=True).to(device)

                # Add decoder_input_ids: initialize with the pad token id
                decoder_input_ids = torch.tensor([[tokenizer.pad_token_id]]).to(device)

                # Forward pass with encoder input and decoder input
                with torch.no_grad():
                    outputs = model(input_ids=inputs['input_ids'], decoder_input_ids=decoder_input_ids)

                # Extract embeddings (e.g., from encoder output or mean pooling)
                embedding = outputs.last_hidden_state.mean(dim=1)  # Mean pooling for simplicity
                embeddings_dict[uniprot_id] = embedding.squeeze(0).cpu().numpy()  # Cache the embedding
            else:
                embeddings_dict[uniprot_id] = [0] * 1024  # Default zero embedding for missing sequences
        except:
            print(f"Error processing uniprot id : {uniprot_id} number {num}")

    return embeddings_dict


# Generate the embeddings for the unique UniProt IDs
embeddings_dict_1 = get_protein_embeddings(protein_list_1)
print("Embeddings generated for protein_list_1")
# Out:
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Processing uniprot id : P14780 number 20
# Processing uniprot id : O75385 number 40
# Processing uniprot id : Q9UNQ0 number 60
# Error processing uniprot id : P09958 number 68
# Processing uniprot id : Q92889 number 80
# Processing uniprot id : P04049 number 100
# Error processing uniprot id : Q9UEW8 number 113
# Error processing uniprot id : Q86V86 number 117
# Processing uniprot id : P49674 number 120
# Error processing uniprot id : P07237 number 121
# Error processing uniprot id : P49336 number 130
# Processing uniprot id : Q05397 number 140
# Processing uniprot id : P22607 number 160
# Processing uniprot id : Q96GG9 number 180
# Processing uniprot id : Q13315 number 200
# Processing uniprot id : P11274 number 220
# Processing uniprot id : Q13535 number 240
# Processing uniprot id : O00141 number 260
# Processing uniprot id : P53667 number 280
# Processing uniprot id : P00403 number 300
# Processing uniprot id : O00571 number 320
# Processing uniprot id : P17812 number 340
# Processing uniprot id : O15245 number 360
# Processing uniprot id : P68371 number 380
# Processing uniprot id : Q13131 number 400
# Processing uniprot id : Q13586 number 420
# Processing uniprot id : Q9H2K8 number 440
# Processing uniprot id : Q9NSY1 number 460
# Processing uniprot id : Q15796 number 480
# Processing uniprot id : Q13554 number 500
# Processing uniprot id : Q13163 number 520
# Processing uniprot id : P49773 number 540
# Processing uniprot id : Q14680 number 560
# Processing uniprot id : P51659 number 580
# Processing uniprot id : O95067 number 600
# Processing uniprot id : O15357 number 620
# Processing uniprot id : Q13155 number 640
# Processing uniprot id : P04181 number 660
# Processing uniprot id : Q9UBC3 number 680
# Processing uniprot id : Q9BYT3 number 700
# Processing uniprot id : P57678 number 720
# Processing uniprot id : Q9GZU7 number 740
# Processing uniprot id : Q9UHL4 number 760
# Processing uniprot id : O15393 number 780
# Processing uniprot id : O60602 number 800
# Processing uniprot id : Q9H4L4 number 820
# Processing uniprot id : P18054 number 840
# Processing uniprot id : O75306 number 860
# Processing uniprot id : Q9H792 number 880
# Processing uniprot id : Q13619 number 900
# Processing uniprot id : Q92993 number 920
# Processing uniprot id : Q6W4X9 number 940
# Processing uniprot id : P35900 number 960
# Processing uniprot id : Q01844 number 980
# Error fetching sequence for nan
# Processing uniprot id : P01189 number 1000
# Processing uniprot id : P21359 number 1020
# Processing uniprot id : P07954 number 1040
# Processing uniprot id : Q16384 number 1060
# Processing uniprot id : O75771 number 1080
# Processing uniprot id : P00326 number 1100
# Processing uniprot id : Q9UNA1 number 1120
# Processing uniprot id : P20749 number 1140
# Processing uniprot id : P06307 number 1160
# Processing uniprot id : Q8NHQ1 number 1180
# Processing uniprot id : P0DML3 number 1200
# Processing uniprot id : Q99607 number 1220
# Processing uniprot id : Q6X9E4 number 1240
# Processing uniprot id : P35637 number 1260
# Processing uniprot id : F5H6H0 number 1280
# Processing uniprot id : P51460 number 1300
# Processing uniprot id : P08727 number 1320
# Processing uniprot id : O75444 number 1340
# Processing uniprot id : P55198 number 1360
# Processing uniprot id : Q9H9S0 number 1380
# Processing uniprot id : A6NNL0 number 1400
# Processing uniprot id : Q99453 number 1420
# Processing uniprot id : Q92786 number 1440
# Processing uniprot id : Q96T37 number 1460
# Processing uniprot id : Q9UJQ4 number 1480
# Processing uniprot id : Q5M775 number 1500
# Processing uniprot id : Q92734 number 1520
# Processing uniprot id : Q01081 number 1540
# Processing uniprot id : Q96ST3 number 1560
# Processing uniprot id : P23771 number 1580
# Error fetching sequence for K02054
# Processing uniprot id : Q14192 number 1600
# Processing uniprot id : P0CG47 number 1620
# Processing uniprot id : Q6GQQ9 number 1640
# Processing uniprot id : Q8IZD9 number 1660
# Processing uniprot id : Q14686 number 1680
# Processing uniprot id : P52597 number 1700
# Processing uniprot id : Q12967 number 1720
# Processing uniprot id : Q15014 number 1740
# Processing uniprot id : Q96CJ1 number 1760
# Processing uniprot id : Q9Y250 number 1780
# Processing uniprot id : Q6QNY1 number 1800
# Processing uniprot id : Q6UWZ7 number 1820
# Processing uniprot id : Q8IZ40 number 1840
# Processing uniprot id : Q99963 number 1860
# Processing uniprot id : P15514 number 1880
# Processing uniprot id : Q9Y6Q9 number 1900
# Processing uniprot id : P13612 number 1920
# Error fetching sequence for BC032729
# Processing uniprot id : Q14134 number 1940
# Processing uniprot id : Q9UM11 number 1960
# Processing uniprot id : O75915 number 1980
# Processing uniprot id : Q8N448 number 2000
# Embeddings generated for protein_list_1

# %%
embeddings_dict_2 = get_protein_embeddings(protein_list_2)
print("Embeddings generated for protein_list_2")
# Out:
# Processing uniprot id : P84101 number 20
# Processing uniprot id : Q9UJ83 number 40
# Processing uniprot id : Q96M29 number 60
# Processing uniprot id : O00629 number 80
# Processing uniprot id : Q12873 number 100
# Error processing uniprot id : Q12873 number 100
# Error processing uniprot id : Q9UGK3 number 117
# Processing uniprot id : Q07065 number 120
# Processing uniprot id : O15123 number 140
# Processing uniprot id : Q14493 number 160
# Processing uniprot id : Q9UPV9 number 180
# Processing uniprot id : P23528 number 200
# Processing uniprot id : Q9Y237 number 220
# Processing uniprot id : P25929 number 240
# Processing uniprot id : O94842 number 260
# Processing uniprot id : P55010 number 280
# Processing uniprot id : Q14498 number 300
# Processing uniprot id : Q9P2N2 number 320
# Processing uniprot id : Q9Y4X5 number 340
# Processing uniprot id : Q99717 number 360
# Processing uniprot id : Q12982 number 380
# Processing uniprot id : P16435 number 400
# Processing uniprot id : Q92692 number 420
# Processing uniprot id : O95786 number 440
# Processing uniprot id : P25325 number 460
# Processing uniprot id : Q96CG8 number 480
# Error fetching sequence for 1743003
# Processing uniprot id : Q53HL2 number 500
# Processing uniprot id : Q6S5L8 number 520
# Processing uniprot id : Q15696 number 540
# Processing uniprot id : Q5T0W9 number 560
# Processing uniprot id : Q96JH8 number 580
# Processing uniprot id : P25205 number 600
# Processing uniprot id : Q9Y2W1 number 620
# Processing uniprot id : Q9Y2S7 number 640
# Processing uniprot id : P15954 number 660
# Processing uniprot id : Q9H869 number 680
# Processing uniprot id : O00303 number 700
# Processing uniprot id : Q07020 number 720
# Processing uniprot id : P12236 number 740
# Processing uniprot id : Q9UKD2 number 760
# Processing uniprot id : Q9P2I0 number 780
# Processing uniprot id : H7BY36 number 800
# Processing uniprot id : E9PNW8 number 820
# Processing uniprot id : P39656 number 840
# Processing uniprot id : H7BYD0 number 860
# Processing uniprot id : B0QYD3 number 880
# Processing uniprot id : Q4TT34 number 900
# Processing uniprot id : Q00325 number 920
# Processing uniprot id : Q9BRK5 number 940
# Processing uniprot id : O60313 number 960
# Processing uniprot id : Q9HAT0 number 980
# Processing uniprot id : A1L0T0 number 1000
# Processing uniprot id : Q14974 number 1020
# Processing uniprot id : P50213 number 1040
# Processing uniprot id : O94829 number 1060
# Processing uniprot id : O94906 number 1080
# Processing uniprot id : P49427 number 1100
# Processing uniprot id : Q1KMD3 number 1120
# Processing uniprot id : O43660 number 1140
# Processing uniprot id : P23246 number 1160
# Processing uniprot id : O15055 number 1180
# Processing uniprot id : Q86SZ2 number 1200
# Processing uniprot id : Q00403 number 1220
# Processing uniprot id : Q9NYL9 number 1240
# Processing uniprot id : O43251 number 1260
# Processing uniprot id : Q9UKK9 number 1280
# Processing uniprot id : Q9BQ70 number 1300
# Processing uniprot id : P31689 number 1320
# Processing uniprot id : P42766 number 1340
# Processing uniprot id : Q8N5C6 number 1360
# Processing uniprot id : P20042 number 1380
# Processing uniprot id : Q02413 number 1400
# Processing uniprot id : P55209 number 1420
# Processing uniprot id : Q9P015 number 1440
# Processing uniprot id : Q59GN2 number 1460
# Processing uniprot id : Q9NZT1 number 1480
# Processing uniprot id : Q13601 number 1500
# Processing uniprot id : P60468 number 1520
# Processing uniprot id : Q9NWB6 number 1540
# Processing uniprot id : P61224 number 1560
# Processing uniprot id : Q9Y4P3 number 1580
# Processing uniprot id : Q8TF74 number 1600
# Processing uniprot id : A6NNY8 number 1620
# Processing uniprot id : Q9UHQ9 number 1640
# Processing uniprot id : P05161 number 1660
# Processing uniprot id : Q96D71 number 1680
# Processing uniprot id : B2RPK0 number 1700
# Processing uniprot id : Q96RF0 number 1720
# Processing uniprot id : Q9BTW9 number 1740
# Processing uniprot id : Q14139 number 1760
# Processing uniprot id : P31930 number 1780
# Processing uniprot id : P06703 number 1800
# Processing uniprot id : Q8IWW6 number 1820
# Processing uniprot id : Q8IWJ2 number 1840
# Processing uniprot id : Q9Y3B2 number 1860
# Processing uniprot id : P14550 number 1880
# Processing uniprot id : Q9BYN8 number 1900
# Processing uniprot id : Q9Y6W5 number 1920
# Processing uniprot id : Q5TAQ9 number 1940
# Processing uniprot id : O75347 number 1960
# Processing uniprot id : Q6P087 number 1980
# Processing uniprot id : Q7L266 number 2000
# Embeddings generated for protein_list_2

# %%
embeddings_dict_3 = get_protein_embeddings(protein_list_3)
print("Embeddings generated for protein_list_3")
# Out:
# Processing uniprot id : Q14643 number 20
# Processing uniprot id : O43246 number 40
# Processing uniprot id : Q9BZD6 number 60
# Processing uniprot id : Q53GZ6 number 80
# Processing uniprot id : Q9H201 number 100
# Processing uniprot id : Q7Z739 number 120
# Processing uniprot id : Q9NWU5 number 140
# Processing uniprot id : Q7Z7H5 number 160
# Error processing uniprot id : Q9HC36 number 174
# Processing uniprot id : P0DOY2 number 180
# Processing uniprot id : Q6WCQ1 number 200
# Processing uniprot id : Q96SB8 number 220
# Processing uniprot id : Q9UBI6 number 240
# Processing uniprot id : Q9UK22 number 260
# Processing uniprot id : Q5VZ89 number 280
# Error processing uniprot id : Q9HCC0 number 288
# Processing uniprot id : Q9BZF9 number 300
# Error processing uniprot id : P09012 number 303
# Processing uniprot id : O15400 number 320
# Processing uniprot id : O95208 number 340
# Processing uniprot id : P42167 number 360
# Processing uniprot id : Q13277 number 380
# Processing uniprot id : Q53GL0 number 400
# Processing uniprot id : Q86UP2 number 420
# Processing uniprot id : Q8N9N7 number 440
# Processing uniprot id : Q92738 number 460
# Processing uniprot id : Q9BQE4 number 480
# Processing uniprot id : Q9HC07 number 500
# Processing uniprot id : Q9P0T7 number 520
# Processing uniprot id : Q9Y2H0 number 540
# Processing uniprot id : Q6ZVX7 number 560
# Error processing uniprot id : Q01780 number 569
# Processing uniprot id : Q6PJG2 number 580
# Processing uniprot id : Q5T3J3 number 600
# Processing uniprot id : Q7Z2W4 number 620
# Processing uniprot id : Q96G01 number 640
# Processing uniprot id : Q9Y5Z7 number 660
# Processing uniprot id : Q13042 number 680
# Processing uniprot id : Q9Y4F1 number 700
# Processing uniprot id : Q96N67 number 720
# Processing uniprot id : O95140 number 740
# Processing uniprot id : P54652 number 760
# Processing uniprot id : P16401 number 780
# Processing uniprot id : P80188 number 800
# Processing uniprot id : Q9BYD2 number 820
# Processing uniprot id : Q6IAN0 number 840
# Processing uniprot id : Q9UI08 number 860
# Processing uniprot id : Q8WTT2 number 880
# Error processing uniprot id : O75431 number 894
# Processing uniprot id : Q6ZVM7 number 900
# Processing uniprot id : P05362 number 920
# Error processing uniprot id : Q99627 number 928
# Error processing uniprot id : Q08554 number 938
# Processing uniprot id : P80723 number 940
# Processing uniprot id : Q9NXS3 number 960
# Processing uniprot id : Q53HC5 number 980
# Processing uniprot id : Q9UBB5 number 1000
# Processing uniprot id : Q9P121 number 1020
# Processing uniprot id : O75563 number 1040
# Error processing uniprot id : Q9H063 number 1058
# Processing uniprot id : Q9NPC8 number 1060
# Processing uniprot id : Q6PH81 number 1080
# Error processing uniprot id : F5H212 number 1089
# Processing uniprot id : O94913 number 1100
# Processing uniprot id : O15014 number 1120
# Processing uniprot id : Q9P2N6 number 1140
# Processing uniprot id : P39019 number 1160
# Processing uniprot id : D3YTB1 number 1180
# Processing uniprot id : Q96CT7 number 1200
# Error processing uniprot id : P54577 number 1210
# Processing uniprot id : Q52LJ0 number 1220
# Processing uniprot id : C9JCK5 number 1240
# Processing uniprot id : Q9Y2I1 number 1260
# Processing uniprot id : Q7Z7L7 number 1280
# Processing uniprot id : O75525 number 1300
# Processing uniprot id : P49757 number 1320
# Processing uniprot id : Q9Y2W2 number 1340
# Processing uniprot id : Q15650 number 1360
# Processing uniprot id : Q6ZUT6 number 1380
# Processing uniprot id : P20908 number 1400
# Processing uniprot id : Q5TYW2 number 1420
# Processing uniprot id : Q03468 number 1440
# Error processing uniprot id : P30040 number 1441
# Processing uniprot id : O43896 number 1460
# Processing uniprot id : Q12857 number 1480
# Processing uniprot id : Q9H0H5 number 1500
# Error processing uniprot id : O43295 number 1508
# Processing uniprot id : Q14142 number 1520
# Processing uniprot id : P01893 number 1540
# Processing uniprot id : P67812 number 1560
# Processing uniprot id : P08237 number 1580
# Processing uniprot id : Q9Y485 number 1600
# Processing uniprot id : Q9NZC9 number 1620
# Processing uniprot id : A2A3N6 number 1640
# Processing uniprot id : Q9UKX3 number 1660
# Processing uniprot id : O95996 number 1680
# Processing uniprot id : Q9Y3Z3 number 1700
# Processing uniprot id : O75147 number 1720
# Processing uniprot id : Q86UC2 number 1740
# Processing uniprot id : Q92685 number 1760
# Processing uniprot id : Q49AG3 number 1780
# Processing uniprot id : O60343 number 1800
# Processing uniprot id : B4DRD7 number 1820
# Error processing uniprot id : B4DGN8 number 1836
# Processing uniprot id : B4DZC0 number 1840
# Processing uniprot id : P69849 number 1860
# Processing uniprot id : P68036 number 1880
# Processing uniprot id : Q9BTV5 number 1900
# Embeddings generated for protein_list_3

# %%
embeddings_dict = {**embeddings_dict_1, **embeddings_dict_2, **embeddings_dict_3}

# %%
print(len(embeddings_dict))
# Out:
# 5914

# %%
while True:
    missing_ids = [m_id for m_id in protein_list if m_id not in embeddings_dict]
    if len(missing_ids) == 0:
        break
    print("Iteration ", len(missing_ids))
    new_dict = get_protein_embeddings(missing_ids)
    embeddings_dict.update(new_dict)
# Out:
# Iteration  20
# Processing uniprot id : B4DGN8 number 20

# %%
with open("embeddings_dict.pkl", "wb") as f:
    pickle.dump(embeddings_dict, f)
